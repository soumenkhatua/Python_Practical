# %%
1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave
2 .Total working days for each agents 
3. Total query that you hvae taken 
4. total Feedback that you have received 
5. a agent name who have average rating between 3.5 to 4 
6 . Agent name who have rating lesss then 3.5 
7 . agent name who have rating more then 4.5 
8 . how many feedaback agents have received more then 4.5 average
9 . average weekly response time for each agent 
10 . average weekely resolution time for each agents 
11 . list of all agents name 
12 . percentage of chat on which they have received a feedback 
13 . Total contributation hour for each and every agents weekly basis 
14. total percentage of active hour for a month

# %%
import pandas as pd

# %%
agent_data= pd.read_excel(r"C:\Users\soume\data fsds\30th_july_task\AgentPerformance (1).xlsx",skiprows= 1)
# Out:
# C:\Users\soume\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
agent_data
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# 3                 00:01:04                00:15:46            4.71
# 4                 00:01:11                00:16:33            3.67
# ...                    ...                     ...             ...
# 2155              00:00:00                00:00:00            0.00
# 2156              00:00:00                00:00:00            0.00
# 2157              00:00:00                00:00:00            0.00
# 2158              00:00:00                00:00:00            0.00
# 2159              00:00:00                00:00:00            0.00
#
#       Total Feedback
# 0                  9
# 1                  7
# 2                 11
# 3                  7
# 4                  6
# ...              ...
# 2155               0
# 2156               0
# 2157               0
# 2158               0
# 2159               0
#
# [2160 rows x 8 columns]

# %%
agent_data.dtypes
# Out:
# SL No                        int64
# Date                        object
# Agent Name                  object
# Total Chats                  int64
# Average Response Time       object
# Average Resolution Time     object
# Average Rating             float64
# Total Feedback               int64
# dtype: object

# %% [markdown]
# # 1 .Find out there avarage rating on weekly basis keep this in a mind that they take two days of leave

# %%
agent_data['WEEK']=pd.to_datetime(agent_data['Date'])

# %%
agent_data
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# 3                 00:01:04                00:15:46            4.71
# 4                 00:01:11                00:16:33            3.67
# ...                    ...                     ...             ...
# 2155              00:00:00                00:00:00            0.00
# 2156              00:00:00                00:00:00            0.00
# 2157              00:00:00                00:00:00            0.00
# 2158              00:00:00                00:00:00            0.00
# 2159              00:00:00                00:00:00            0.00
#
#       Total Feedback       week       WEEK
# 0                  9 2022-07-30 2022-07-30
# 1                  7 2022-07-30 2022-07-30
# 2                 11 2022-07-30 2022-07-30
# 3                  7 2022-07-30 2022-07-30
# 4                  6 2022-07-30 2022-07-30
# ...              ...        ...        ...
# 2155               0 2022-07-01 2022-07-01
# 2156               0 2022-07-01 2022-07-01
# 2157               0 2022-07-01 2022-07-01
# 2158               0 2022-07-01 2022-07-01
# 2159               0 2022-07-01 2022-07-01
#
# [2160 rows x 10 columns]

# %%
agent_data['date_week']=agent_data['WEEK'].dt.isocalendar().week

# %%
agent_data
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# 3                 00:01:04                00:15:46            4.71
# 4                 00:01:11                00:16:33            3.67
# ...                    ...                     ...             ...
# 2155              00:00:00                00:00:00            0.00
# 2156              00:00:00                00:00:00            0.00
# 2157              00:00:00                00:00:00            0.00
# 2158              00:00:00                00:00:00            0.00
# 2159              00:00:00                00:00:00            0.00
#
#       Total Feedback       week       WEEK  date_week
# 0                  9 2022-07-30 2022-07-30         30
# 1                  7 2022-07-30 2022-07-30         30
# 2                 11 2022-07-30 2022-07-30         30
# 3                  7 2022-07-30 2022-07-30         30
# 4                  6 2022-07-30 2022-07-30         30
# ...              ...        ...        ...        ...
# 2155               0 2022-07-01 2022-07-01         26
# 2156               0 2022-07-01 2022-07-01         26
# 2157               0 2022-07-01 2022-07-01         26
# 2158               0 2022-07-01 2022-07-01         26
# 2159               0 2022-07-01 2022-07-01         26
#
# [2160 rows x 11 columns]

# %%
agent_data['date_days']=agent_data['WEEK'].dt.day
agent_data
# Out:
#       SL No        Date          Agent Name  Total Chats  \
# 0         1  2022-07-30        Prerna Singh           11
# 1         2  2022-07-30       Nandani Gupta           11
# 2         3  2022-07-30          Ameya Jain           14
# 3         4  2022-07-30       Mahesh Sarade           14
# 4         5  2022-07-30              Swati            14
# ...     ...         ...                 ...          ...
# 2155   2156  2022-07-01   Sowmiya Sivakumar            0
# 2156   2157  2022-07-01             Nitin M            0
# 2157   2158  2022-07-01              Vivek             0
# 2158   2159  2022-07-01       Ayushi Mishra            0
# 2159   2160  2022-07-01  Chaitra K Hiremath            0
#
#      Average Response Time Average Resolution Time  Average Rating  \
# 0                 00:00:38                00:04:20            4.11
# 1                 00:01:15                00:28:25            3.14
# 2                 00:00:30                00:11:36            4.55
# 3                 00:01:04                00:15:46            4.71
# 4                 00:01:11                00:16:33            3.67
# ...                    ...                     ...             ...
# 2155              00:00:00                00:00:00            0.00
# 2156              00:00:00                00:00:00            0.00
# 2157              00:00:00                00:00:00            0.00
# 2158              00:00:00                00:00:00            0.00
# 2159              00:00:00                00:00:00            0.00
#
#       Total Feedback       week       WEEK  date_week  date_days
# 0                  9 2022-07-30 2022-07-30         30         30
# 1                  7 2022-07-30 2022-07-30         30         30
# 2                 11 2022-07-30 2022-07-30         30         30
# 3                  7 2022-07-30 2022-07-30         30         30
# 4                  6 2022-07-30 2022-07-30         30         30
# ...              ...        ...        ...        ...        ...
# 2155               0 2022-07-01 2022-07-01         26          1
# 2156               0 2022-07-01 2022-07-01         26          1
# 2157               0 2022-07-01 2022-07-01         26          1
# 2158               0 2022-07-01 2022-07-01         26          1
# 2159               0 2022-07-01 2022-07-01         26          1
#
# [2160 rows x 12 columns]

# %%
agent_data_mean=pd.DataFrame(agent_data.groupby(['Agent Name','date_week'])['Average Rating'].mean())

# %%
agent_data_mean
# Out:
#                       Average Rating
# Agent Name date_week
# Abhishek   26               0.000000
#            27               0.000000
#            28               0.000000
#            29               0.000000
#            30               0.000000
# ...                              ...
# Zeeshan    26               0.000000
#            27               1.307143
#            28               2.948571
#            29               3.180000
#            30               2.760000
#
# [350 rows x 1 columns]

# %% [markdown]
# # 2 .Total working days for each agents

# %%
agent_data.groupby('Agent Name')['date_days'].count().to_frame()
# Out:
#                date_days
# Agent Name
# Abhishek              30
# Aditya                30
# Aditya Shinde         30
# Aditya_iot            30
# Amersh                30
# ...                  ...
# Uday Mishra           30
# Vasanth P             30
# Vivek                 30
# Wasim                 30
# Zeeshan               30
#
# [70 rows x 1 columns]

# %% [markdown]
# # 3. Total query that you have taken

# %%
agent_data.groupby("Agent Name")["Total Chats"].sum().to_frame()
# Out:
#                Total Chats
# Agent Name
# Abhishek                 0
# Aditya                   0
# Aditya Shinde          277
# Aditya_iot             231
# Amersh                   0
# ...                    ...
# Uday Mishra              0
# Vasanth P                0
# Vivek                   44
# Wasim                  433
# Zeeshan                542
#
# [70 rows x 1 columns]

# %% [markdown]
# # 4. Total Feedback that you have received

# %%
agent_data.groupby("Agent Name")["Total Chats"].sum().to_frame()
# Out:
#                Total Chats
# Agent Name
# Abhishek                 0
# Aditya                   0
# Aditya Shinde          277
# Aditya_iot             231
# Amersh                   0
# ...                    ...
# Uday Mishra              0
# Vasanth P                0
# Vivek                   44
# Wasim                  433
# Zeeshan                542
#
# [70 rows x 1 columns]

# %%
agent_data.groupby

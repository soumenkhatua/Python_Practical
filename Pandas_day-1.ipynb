# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\soume\data fsds\Attribute Dataset.xlsx")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
pd.read_excel(r"C:\Users\soume\data fsds\Attribute Dataset.xlsx",sheet_name = 'sudh',header = None)

# By default it takes sheet1 if you want to put other sheet then you have to mention the sheet name respectively.
# Out:
#           0         1         2
# 0    hgdrfd     bggbg   fggbfc
# 1      ffdf      fffv       bbb
# 2     gbffd       mjj       sdc
# 3   fdfdbbb        bb    ccdccs
# 4       fbf   hmmbhhm      xccx
# 5     ffdbf    nvhnvn     cxxc
# 6      nfgn    mnhhnv       yhg
# 7     bfbfd      bbmh  ggfgffdz
# 8       bgg      ntgr    deddwd
# 9  bffbbfbf  fggfbbbf     wdwwq

# %%
pd.read_excel(r"C:\Users\soume\data fsds\Attribute Dataset.xlsx",sheet_name = 'sudh1')
# Out:
#     erihehi        egr    ggre
# 0   fhiouoi      grtgg     ggg
# 1       NaN        trg  tggtrg
# 2  ibhiufgh  iuyuifghu  gtrtgg
# 3       NaN        NaN      gg
# 4       NaN     bfgfgb     NaN

# %%
pd.read_excel(r"C:\Users\soume\data fsds\Attribute Dataset.xlsx",sheet_name = 'sudh1',header = None , names=["A" , "B" ,"C"])
# Out:
#           A          B       C
# 0   erihehi        egr    ggre
# 1   fhiouoi      grtgg     ggg
# 2       NaN        trg  tggtrg
# 3  ibhiufgh  iuyuifghu  gtrtgg
# 4       NaN        NaN      gg
# 5       NaN     bfgfgb     NaN

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
 df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.head(2)
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
df.tail(4)
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline Material  FabricType Decoration Pattern Type  Recommendation
# 496    empire   cotton         NaN        NaN          NaN               0
# 497    empire   cotton         NaN       lace        solid               1
# 498    empire     silk  broadcloth   applique        print               1
# 499    empire   cotton    Corduroy       lace        solid               0

# %%
pd.read_csv(r"C:\Users\soume\data fsds\haberman.csv")
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
pd.read_csv(r"C:\Users\soume\data fsds\haberman.csv" ,header = None,names = ["Age" , "Patients year of operations" , "Number of positive" , "Survival status"])
# Out:
#      Age  Patients year of operations  Number of positive  Survival status
# 0     30                           64                   1                1
# 1     30                           62                   3                1
# 2     30                           65                   0                1
# 3     31                           59                   2                1
# 4     31                           65                   4                1
# ..   ...                          ...                 ...              ...
# 301   75                           62                   1                1
# 302   76                           67                   0                1
# 303   77                           65                   3                1
# 304   78                           65                   1                2
# 305   83                           58                   2                2
#
# [306 rows x 4 columns]

# %%
pd.read_csv(r"C:\Users\soume\data fsds\haberman1.csv",header = None ,sep = "@")
# sep= "@" is menas that all the "@" will be separate from the data.
# Out:
#       0   1  2  3
# 0    30  64  1  1
# 1    30  62  3  1
# 2    30  65  0  1
# 3    31  59  2  1
# 4    31  65  4  1
# ..   ..  .. .. ..
# 301  75  62  1  1
# 302  76  67  0  1
# 303  77  65  3  1
# 304  78  65  1  2
# 305  83  58  2  2
#
# [306 rows x 4 columns]

# %%
pd.read_csv("https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv")
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
data_csv = pd.read_csv("https://raw.githubusercontent.com/stefanb/gurs-rpe/master/data/NA.csv")
data_csv
# Out:
#       ENOTA    NA_MID  NA_ID     NA_UIME NA_DJ    OB_MID  POV_KM2        D_OD  \
# 0       NaN  10083931      1  Ajdovščina   NaN  11026516     6.95  1995/01/01
# 1       NaN  10083940      2      Batuje   NaN  11026516     2.83  1995/01/01
# 2       NaN  10083958      3        Bela   NaN  11026516     4.90  1995/01/01
# 3       NaN  10083966      4        Brje   NaN  11026516     5.35  1995/01/01
# 4       NaN  10083974      5     Budanje   NaN  11026516     5.33  1995/01/01
# ...     ...       ...    ...         ...   ...       ...      ...         ...
# 6031    NaN  24031837     22       Draga   NaN  11026907     1.91  2007/05/29
# 6032    NaN  24032698     23     Podgozd   NaN  11026907     1.02  2007/06/14
# 6033    NaN  24034160     24     Podkraj   NaN  11026907     2.46  2007/08/06
# 6034    NaN  24034313     25        Suša   NaN  11026907     1.01  2007/07/26
# 6035    NaN  24267245     14    Šestdobe   NaN  11027245     1.12  2013/05/09
#
# ...

# %%
data_csv.columns
# Out:
# Index(['ENOTA', 'NA_MID', 'NA_ID', 'NA_UIME', 'NA_DJ', 'OB_MID', 'POV_KM2',
#        'D_OD', 'DV_OD', 'STATUS', 'CEN_E', 'CEN_N'],
#       dtype='object')

# %%
a = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")
a
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(a)
# Out:
# list

# %%
a[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
js = pd.read_json("https://api.github.com/repos/pandas-dev/pandas/issues")
js

#Reading json (Java Script Object Notation) format: Combination of Dictionaries: We can use json viewer online to understand json in better way
#Keys become our column and Row becomes our values of those keys
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
js.head(2)
# Out:
#                                                  url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
#
#                                           labels_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                         comments_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
#
#                                             html_url          id  \
# 0    https://github.com/pandas-dev/pandas/pull/47929  1325322319
# ...

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
js["repository_url"]
# Out:
# 0     https://api.github.com/repos/pandas-dev/pandas
# 1     https://api.github.com/repos/pandas-dev/pandas
# 2     https://api.github.com/repos/pandas-dev/pandas
# 3     https://api.github.com/repos/pandas-dev/pandas
# 4     https://api.github.com/repos/pandas-dev/pandas
# 5     https://api.github.com/repos/pandas-dev/pandas
# 6     https://api.github.com/repos/pandas-dev/pandas
# 7     https://api.github.com/repos/pandas-dev/pandas
# 8     https://api.github.com/repos/pandas-dev/pandas
# 9     https://api.github.com/repos/pandas-dev/pandas
# 10    https://api.github.com/repos/pandas-dev/pandas
# 11    https://api.github.com/repos/pandas-dev/pandas
# 12    https://api.github.com/repos/pandas-dev/pandas
# 13    https://api.github.com/repos/pandas-dev/pandas
# 14    https://api.github.com/repos/pandas-dev/pandas
# 15    https://api.github.com/repos/pandas-dev/pandas
# 16    https://api.github.com/repos/pandas-dev/pandas
# 17    https://api.github.com/repos/pandas-dev/pandas
# ...

# %%
js["user"]
# Out:
# 0     {'login': 'skrawcz', 'id': 2328071, 'node_id':...
# 1     {'login': 'attack68', 'id': 24256554, 'node_id...
# 2     {'login': 'Dr-Irv', 'id': 15113894, 'node_id':...
# 3     {'login': 'Codeberg-AsGithubAlternative-buhtz'...
# 4     {'login': 'dannyi96', 'id': 15380498, 'node_id...
# 5     {'login': 'weikhor', 'id': 36619387, 'node_id'...
# 6     {'login': 'seanslma', 'id': 30691708, 'node_id...
# 7     {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 8     {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 9     {'login': 'PriestlyAdejo', 'id': 108146732, 'n...
# 10    {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 11    {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 12    {'login': 'dannyi96', 'id': 15380498, 'node_id...
# 13    {'login': 'bherwerth', 'id': 108834862, 'node_...
# 14    {'login': 'StefRe', 'id': 19879328, 'node_id':...
# 15    {'login': 'windowshopr', 'id': 40477419, 'node...
# 16    {'login': 'bzhaoopenstack', 'id': 11386522, 'n...
# ...

# %%
js["user"][0]
# Out:
# {'login': 'skrawcz',
#  'id': 2328071,
#  'node_id': 'MDQ6VXNlcjIzMjgwNzE=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/2328071?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/skrawcz',
#  'html_url': 'https://github.com/skrawcz',
#  'followers_url': 'https://api.github.com/users/skrawcz/followers',
#  'following_url': 'https://api.github.com/users/skrawcz/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/skrawcz/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/skrawcz/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/skrawcz/subscriptions',
#  'organizations_url': 'https://api.github.com/users/skrawcz/orgs',
#  'repos_url': 'https://api.github.com/users/skrawcz/repos',
#  'events_url': 'https://api.github.com/users/skrawcz/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/skrawcz/received_events',
#  'type': 'User',
#  'site_admin': False}

# %%
df = pd.read_excel(r"C:\Users\soume\data fsds\Attribute Dataset.xlsx")

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_json("json_transfer.json")
# Converting data to json

# %%
pwd
# Out:
# 'C:\\Users\\soume\\My class work@iNeuron'

# %%
#pwd #Present Working Directory
#Spark Dataframe is faster than Pandas Dataframe because it uses optimizer internally.

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_csv("D://test22112.csv",index= False)

# %%
pwd
# Out:
# 'C:\\Users\\soume\\My class work@iNeuron'
